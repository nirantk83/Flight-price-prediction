# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as pt
import seaborn as sns
import datetime as dt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('Clean_Dataset.csv')

# %%
df
# Out:
#         Unnamed: 0   airline   flight source_city departure_time stops  \
# 0                0  SpiceJet  SG-8709       Delhi        Evening  zero
# 1                1  SpiceJet  SG-8157       Delhi  Early_Morning  zero
# 2                2   AirAsia   I5-764       Delhi  Early_Morning  zero
# 3                3   Vistara   UK-995       Delhi        Morning  zero
# 4                4   Vistara   UK-963       Delhi        Morning  zero
# ...            ...       ...      ...         ...            ...   ...
# 300148      300148   Vistara   UK-822     Chennai        Morning   one
# 300149      300149   Vistara   UK-826     Chennai      Afternoon   one
# 300150      300150   Vistara   UK-832     Chennai  Early_Morning   one
# 300151      300151   Vistara   UK-828     Chennai  Early_Morning   one
# 300152      300152   Vistara   UK-822     Chennai        Morning   one
#
#          arrival_time destination_city     class  duration  days_left  price
# ...

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
#as can be seen there is column which are not as imp si we can delete it

# %%
df
# Out:
#          airline   flight source_city departure_time stops   arrival_time  \
# 0       SpiceJet  SG-8709       Delhi        Evening  zero          Night
# 1       SpiceJet  SG-8157       Delhi  Early_Morning  zero        Morning
# 2        AirAsia   I5-764       Delhi  Early_Morning  zero  Early_Morning
# 3        Vistara   UK-995       Delhi        Morning  zero      Afternoon
# 4        Vistara   UK-963       Delhi        Morning  zero        Morning
# ...          ...      ...         ...            ...   ...            ...
# 300148   Vistara   UK-822     Chennai        Morning   one        Evening
# 300149   Vistara   UK-826     Chennai      Afternoon   one          Night
# 300150   Vistara   UK-832     Chennai  Early_Morning   one          Night
# 300151   Vistara   UK-828     Chennai  Early_Morning   one        Evening
# 300152   Vistara   UK-822     Chennai        Morning   one        Evening
#
#        destination_city     class  duration  days_left  price
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           300153 non-null  object
#  1   flight            300153 non-null  object
#  2   source_city       300153 non-null  object
#  3   departure_time    300153 non-null  object
#  4   stops             300153 non-null  object
#  5   arrival_time      300153 non-null  object
#  6   destination_city  300153 non-null  object
#  7   class             300153 non-null  object
#  8   duration          300153 non-null  float64
#  9   days_left         300153 non-null  int64
#  10  price             300153 non-null  int64
# dtypes: float64(1), int64(2), object(8)
# memory usage: 25.2+ MB

# %%
df.isnull().sum()
# Out:
# airline             0
# flight              0
# source_city         0
# departure_time      0
# stops               0
# arrival_time        0
# destination_city    0
# class               0
# duration            0
# days_left           0
# price               0
# dtype: int64

# %%
#there is no null values in dataset so it s clean dataset

# %%
#as can be seen from this there is no NUll values in dataset

# %%
df['arrival_time'].value_counts()
# Out:
# Night            91538
# Evening          78323
# Morning          62735
# Afternoon        38139
# Early_Morning    15417
# Late_Night       14001
# Name: arrival_time, dtype: int64

# %%
#df['days_left'].value_counts()

# %%
df['class'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#there is more economy class seat as compared to business class

# %%
#To predict price of flight we have to convert all object to int,float to build and apply model on ths dataset

# %%
from sklearn.preprocessing import LabelEncoder
lr=LabelEncoder()
#we import the lable encoder from sklearn libret to convert object to int,float

# %%
df['airline']=lr.fit_transform(df['airline'])
df['flight']=lr.fit_transform(df['flight'])
df['source_city']=lr.fit_transform(df['source_city'])
df['departure_time']=lr.fit_transform(df['departure_time'])
df['stops']=lr.fit_transform(df['stops'])
df['arrival_time']=lr.fit_transform(df['arrival_time'])
df['destination_city']=lr.fit_transform(df['destination_city'])
df['class']=lr.fit_transform(df['class'])
df['duration']=lr.fit_transform(df['duration'])
df['days_left']=lr.fit_transform(df['days_left'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300153 entries, 0 to 300152
# Data columns (total 11 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   airline           300153 non-null  int32
#  1   flight            300153 non-null  int32
#  2   source_city       300153 non-null  int32
#  3   departure_time    300153 non-null  int32
#  4   stops             300153 non-null  int32
#  5   arrival_time      300153 non-null  int32
#  6   destination_city  300153 non-null  int32
#  7   class             300153 non-null  int32
#  8   duration          300153 non-null  int64
#  9   days_left         300153 non-null  int64
#  10  price             300153 non-null  int64
# dtypes: int32(8), int64(3)
# memory usage: 16.0 MB

# %%
df.drop(['flight','arrival_time'],axis=1,inplace=True)

# %%
df
# Out:
#         airline  source_city  departure_time  stops  destination_city  class  \
# 0             4            2               2      2                 5      1
# 1             4            2               1      2                 5      1
# 2             0            2               1      2                 5      1
# 3             5            2               4      2                 5      1
# 4             5            2               4      2                 5      1
# ...         ...          ...             ...    ...               ...    ...
# 300148        5            1               4      0                 3      0
# 300149        5            1               0      0                 3      0
# 300150        5            1               1      0                 3      0
# 300151        5            1               1      0                 3      0
# 300152        5            1               4      0                 3      0
#
#         duration  days_left  price
# ...

# %%
x=df.iloc[:,:-1]
y=df['price']
#split datadet into x and Y

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.3,random_state=1)

# %%
#model building
from sklearn.linear_model import LinearRegression
Lr=LinearRegression()
Lr.fit(xtrain,ytrain)
ypred=Lr.predict(xtest)

# %%
from sklearn.metrics import r2_score
r2_score(ytest,ypred)
# Out:
# 0.9052906942564461

# %%
airline=int(input('enter airline number with you want to fly'))
source_city=int(input('enter source_city'))
departure_time=int(input('enter departure_time'))

stops=int(input('enter num of stops'))
destination_city=int(input('enter destination_city'))
Class=int(input('enter class'))
duration=int(input('enter duration'))
days_left=int(input('enter days_left'))

res=Lr.predict([[airline,source_city,departure_time,stops,destination_city,Class,duration,days_left]])
print('Your Flight price is :',res,'Rs')
